# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
url = "https://www.residentadvisor.net/events/us/newyork"
resp = requests.get(url)
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1">
# <script>
#             if (typeof dataLayer === 'undefined') {
#                 dataLayer = []
#             }
#         </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# <title>
# 	RA: Events in New York, United States of America
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, new, york, united, states, america" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=nA9uavMPeFtRavUj5m2TICqAtGhp7tbC5z-iw5vW6k81" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=f4eB862zmilD4dOWmR7ebuJfszYQdGcmWXBVo2GCefI1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=ojfhnSS3vQR_E4mHHYGVG8VBKABXIiKyvhub_-LVawo1"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/us/newyork").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "US").setTargeting("Area", "NewYork"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script src="/js/dist/ReactLibs.bundle.js?637346223114944026"></script></head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but subscribe desktop-only desktop-wide-only" data-use-same-tab="true" id="nav-link">
# <a ga-event-action="subscribe-nav-link" ga-event-category="subscriptions" ga-on="click" href="/subscribe">
# <span>Subscribe</span>
# </a>
# </li>
# <li class="but arrow-down temp login" id="profile">Login / Register
# </li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div>
# <div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mStreamland"><a ga-event-action="Streamland" ga-event-category="nav" ga-on="click" href="/events/streamland">
# Streamland</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
#  Artists</a></li>
# <li id="mMixOfTheDay"><a ga-event-action="Mix of the day" ga-event-category="nav" ga-on="click" href="/news/mix-of-the-day/2020/9">
# Mix of the day</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
# DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="https://search.residentadvisor.net/" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=hX3EIxBPUes4W-JFrW9vc2V9eyRDs1p9rgi0LcnlXug1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=SCtA5z9vnBIQK6ZI-wtyD14u0Lv-S6kQhwTW5lgrMYQ1"></script>
# <script src="/bundles/analytics-js?v=pUK2ZxBTfTo6P0-8Xh1_QmhiGk4YBwWiTKDOFLGXwbg1"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./newyork?cc=us&amp;an=newyork" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="aAXUDVWia/RXLHWG9+yhfDHJuxirGonDM/hDY8sXp6YFJjADKs7w3aMfkSAq2sIFlikUkK74R8JOCb5FIQUvk6z349g="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="alt nobreak">
# <section class="content clearfix">
# <h1 class="listing-heading heading">Popular events in New York</h1>
# <div class="strip slide small" data-type="events" id="events-listing">
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Wed, 2 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1422373"><img class="nohide" src="/images/events/flyer/2020/9/us-0902-1422373-list.jpg"/></a>
# <p class="counter nohide">
# <span>2</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1422373">
# <h1>
# Outdoor Films: Sign o' the Times
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=105873">Nowadays</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 5 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1387223"><img class="nohide" src="/images/events/flyer/2020/4/us-0411-1387223-list.jpg"/></a>
# <p class="counter nohide">
# <span>17</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1387223">
# <h1>
# Cuff Tour: Amine Edge &amp; Dance with Raw Phonics
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=132098">Pier 15</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 5 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1420885"><img class="nohide" src="/images/events/flyer/2020/8/us-0815-1420885-list.jpg"/></a>
# <p class="counter nohide">
# <span>7</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1420885">
# <h1>
# White Rabbit
# </h1>
# </a>
# <p class="copy nohide">
# Now and Then
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Wed, 9 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1401171"><img class="nohide" src="/images/events/flyer/2020/9/us-0909-1401171-list.jpg"/></a>
# <p class="counter nohide">
# <span>1</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1401171">
# <h1>
# She Past Away
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=11796">Le Poisson Rouge</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 12 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1408321"><img class="nohide" src="/images/events/flyer/2020/9/us-0912-1408321-list.jpg"/></a>
# <p class="counter nohide">
# <span>2</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1408321">
# <h1>
# Shake That Midnight Yacht Cruise
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=31804">Harbor Lights Yacht</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Thu, 17 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1388575"><img class="nohide" src="/images/events/flyer/2020/9/us-0917-1388575-list.jpg"/></a>
# <p class="counter nohide">
# <span>4</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1388575">
# <h1>
# Cold Waves + Popgun present: Front 242
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=139960">Elsewhere</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 26 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1396670"><img class="nohide" src="/images/events/flyer/2020/4/us-0404-1396670-list.jpg"/></a>
# <p class="counter nohide">
# <span>21</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1396670">
# <h1>
# [RESCHEDULED] Black Party 2020
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=148114">New York Expo Center</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Wed, 30 Sep 2020</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1383946"><img class="nohide" src="/images/events/flyer/2020/5/us-0502-1383946-list.jpg"/></a>
# <p class="counter nohide">
# <span>137</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1383946">
# <h1>
# Monolink - rescheduled
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=143012">Kings Hall - Avant Gardner</a>
# </p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a></a>
# </div>
# <script>
#                             googleAnalytics.sendEventDataOnLoad('events-page', 'popular-events-loaded');
#                        </script>
# </section>
# <section class="iOSOnly content">
# <ul class="phones">
# <li class="f12 pb4 grey">Want RA listings on your mobile?</li>
# <li>
# <div class="but"><a href="https://itunes.apple.com/app/apple-store/id981952703?mt=8">Download the RA Guide</a></div>
# </li>
# </ul>
# </section>
# <div class="banner clearfix">
# <div id="pnlECTOSlot1" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-0"></div>
# </div>
# </div>
# </li>
# <li class="clearfix pt1">
# <div class="page-items content" id="previous-next">
# <ul>
# <li class="but arrow-left left" id="liPrevious">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/newyork/week/2020-08-26">Previous </a>
# </li><li class="but arrow-right right" id="liNext">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/newyork/week/2020-09-09">Next </a>
# </li>
# </ul>
# </div>
# <div class="content clearfix">
# <div class="plus8">
# <div>
# <script src="/bundles/area-country-date-filter-js?v=Q02f5CsIXWPDeOtgJVocYJrwjcQrf96m1qneHFerLLA1"></script>
# <ul class="clearfix classic" data-enableevent="True" id="ulButtons">
# <li class="but arrow-down right" id="liCountry">
# <input id="hdnCountryId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnCountryId" type="hidden" value="2"/>
# <span>US</span><input id="country-name" type="hidden" value="United States of America"/><ul class="links" style="display: none;"><li data-id="7"><a href="/events">Canada</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="20"><a href="/events">Italy</a></li><li data-id="6"><a href="/events">Netherlands</a></li><li data-id="5"><a href="/events">Spain</a></li><li data-id="3"><a href="/events">United Kingdom</a></li><li class="selected" data-id="2"><a href="/events">United States of America</a></li><li data-id="0"><a href="/events">------------</a></li><li data-id="99"><a href="/events">Albania</a></li><li data-id="125"><a href="/events">Algeria</a></li><li data-id="113"><a href="/events">Andorra</a></li><li data-id="127"><a href="/events">Angola</a></li><li data-id="140"><a href="/events">Antigua and Barbuda</a></li><li data-id="16"><a href="/events">Argentina</a></li><li data-id="106"><a href="/events">Armenia</a></li><li data-id="1"><a href="/events">Australia</a></li><li data-id="57"><a href="/events">Austria</a></li><li data-id="108"><a href="/events">Azerbaijan</a></li><li data-id="117"><a href="/events">Bahamas</a></li><li data-id="80"><a href="/events">Bahrain</a></li><li data-id="107"><a href="/events">Bangladesh</a></li><li data-id="73"><a href="/events">Barbados</a></li><li data-id="76"><a href="/events">Belarus</a></li><li data-id="29"><a href="/events">Belgium</a></li><li data-id="34"><a href="/events">Belize</a></li><li data-id="141"><a href="/events">Benin</a></li><li data-id="126"><a href="/events">Bermuda</a></li><li data-id="142"><a href="/events">Bhutan</a></li><li data-id="85"><a href="/events">Bolivia</a></li><li data-id="74"><a href="/events">Bosnia and Herzegovina</a></li><li data-id="143"><a href="/events">Botswana</a></li><li data-id="28"><a href="/events">Brazil</a></li><li data-id="47"><a href="/events">Bulgaria</a></li><li data-id="144"><a href="/events">Burkina Faso</a></li><li data-id="110"><a href="/events">Cambodia</a></li><li data-id="145"><a href="/events">Cameroon</a></li><li data-id="7"><a href="/events">Canada</a></li><li data-id="92"><a href="/events">Cayman Islands</a></li><li data-id="25"><a href="/events">Chile</a></li><li data-id="30"><a href="/events">China</a></li><li data-id="59"><a href="/events">Colombia</a></li><li data-id="10"><a href="/events">Costa Rica</a></li><li data-id="146"><a href="/events">Cote d'Ivoire</a></li><li data-id="46"><a href="/events">Croatia</a></li><li data-id="102"><a href="/events">Cuba</a></li><li data-id="129"><a href="/events">Curacao</a></li><li data-id="82"><a href="/events">Cyprus</a></li><li data-id="49"><a href="/events">Czech Republic</a></li><li data-id="147"><a href="/events">Democratic Republic of the Congo</a></li><li data-id="51"><a href="/events">Denmark</a></li><li data-id="66"><a href="/events">Dominican Republic</a></li><li data-id="72"><a href="/events">Ecuador</a></li><li data-id="48"><a href="/events">Egypt</a></li><li data-id="54"><a href="/events">El Salvador</a></li><li data-id="71"><a href="/events">Estonia</a></li><li data-id
</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73360">
# <img class="thumb" src="/images/news/2020/jeff-mils-new-albums-axis-terrence-dixon-tadeo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73360/?comments=1">Post a comment</a>
# </p><a href="/news/73360">
# <h1>Axis Records releases new albums from Jeff Mills, Terrence Dixon and Tadeo</h1>
# </a>
# <p class="copy">All three records are available now.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Sun, 30 Aug 2020</p>
# <a href="/news/73390">
# <img class="thumb" src="/images/news/2020/donna-leake-mix-of-they-day.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73390/?comments=1">Post a comment</a>
# </p><a href="/news/73390">
# <h1>Mix Of The Day: Donna Leake</h1>
# </a>
# <p class="copy">The London selector plays jazz, psych rock and other assorted oddities.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73368">
# <img class="thumb" src="/images/news/2020/carrot-green-dekmantel-mix-of-the-day.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73368/?comments=1">Post a comment</a>
# </p><a href="/news/73368">
# <h1>Mix Of The Day: Carrot Green</h1>
# </a>
# <p class="copy">The Brazilian favourite in the mix for Dekmantel.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 31 Aug 2020</p>
# <a href="/news/73398">
# <img class="thumb" src="/images/news/2020/bbc-3-jamz-supernova.png"/>
# </a>
# <p class="comments light">
# <a href="/news/73398/?comments=1">Post a comment</a>
# </p><a href="/news/73398">
# <h1>BBC Three show featuring Jamz Supernova, SHERELLE asks Is This The End Of Clubbing?</h1>
# </a>
# <p class="copy">Plastician also appears on the 20-minute programme, which is available now on BBC iPlayer.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 28 Aug 2020</p>
# <a href="/news/73378">
# <img class="thumb" src="/images/news/2020/dj-ez-bbc-radio-1.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73378/?comments=1">Post a comment</a>
# </p><a href="/news/73378">
# <h1>BBC Radio 1 reveals latest residents, DJ EZ, Disclosure, Joy Orbison and Amelie Lens</h1>
# </a>
# <p class="copy">SHERELLE, Saoirse, Teki Latex and Eris Drew &amp; Octo Octa will also return.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Sat, 29 Aug 2020</p>
# <a href="/news/73389">
# <img class="thumb" src="/images/news/2020/authentically-plastic-motd-1.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73389/?comments=1">Post a comment</a>
# </p><a href="/news/73389">
# <h1>Mix Of The Day: Authentically Plastic</h1>
# </a>
# <p class="copy">Trippy downtempo sounds for Black Science Fiction.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73366">
# <img class="thumb" src="/images/news/2020/bussey-building-culture-recovery-grant.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73366/?comments=1">Post a comment</a>
# </p><a href="/news/73366">
# <h1>Corsica Studios, Phonox among 135 venues receiving support from the UK Culture Recovery Fund</h1>
# </a>
# <p class="copy">Other venues receiving emergency grants include Manchester's Soup Kitchen and Peckham's CLF Art Cafe, site of the Bussey Building and Rye Wax.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 27 Aug 2020</p>
# <a href="/news/73375">
# <img class="thumb" src="/images/news/2020/toro-y-moi-acemo-ep.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73375/?comments=1">Post a comment</a>
# </p><a href="/news/73375">
# <h1>Toro Y Moi &amp; AceMo release collaborative EP</h1>
# </a>
# <p class="copy">C'mon Les' Go is out now on AceMo's new label, Sonic Messengers.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 28 Aug 2020</p>
# <a href="/news/73387">
# <img class="thumb" src="/images/news/2020/zhao-dai-club-festival-seaside-gold-coast-aranya.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73387/?comments=1">Post a comment</a>
# </p><a href="/news/73387">
# <h1>Beijing club Zhao Dai holds beachside festival with promoters from across China</h1>
# </a>
# <p class="copy">Other venues involved include Elevator, Tag, Oil and All, for a first-of-its-kind festival in China.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 31 Aug 2020</p>
# <a href="/news/73404">
# <img class="thumb" src="/images/news/2020/maceo-plex-new-single-aclu-fundraiser.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/73404/?comments=1">Post a comment</a>
# </p><a href="/news/73404">
# <h1>Maceo Plex releases new single to raise money for the ACLU to fight voter suppression</h1>
# </a>
# <p class="copy">"Nu World" is out now.</p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# </section>
# <span>02 /</span>
# </li>
# </ul>
# </main>
# </form>
# <footer class="clearfix"><ul class="content-list">
# <li>
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col2-3">
# <ul class="pb32">
# <li id="logo-footer"><a href="/">RA</a></li>
# <li class="f12 grey pt16">Copyright © 2020 Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><a ga-event-action="store" ga-event-category="homefooter" ga-on="click" href="https://store.ra.co">RA Store</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a></a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>>

# %%
soup.find('div', id="event-listing").findAll('li')[0].text.replace('/', '').strip()
# Out:
# 'Wed, 02 Sep 2020'

# %%
soup.find('div', id="event-listing").findAll('li')[1].text
# Out:
# "2020-09-02T00:00Outdoor Films: Sign o' the Times at NowadaysN/A2 Attending"

# %%
soup.find('div', id='event-listing').findAll('li')[0]
# Out:
# <li><p class="eventDate date"><a href="/events.aspx?ai=8&amp;v=day&amp;mn=9&amp;yr=2020&amp;dy=2"><span>Wed, 02 Sep 2020 /</span></a></p></li>

# %%
soup.find('div', id="event-listing").findAll('li')[0].find(class_='eventDate date')
# Out:
# <p class="eventDate date"><a href="/events.aspx?ai=8&amp;v=day&amp;mn=9&amp;yr=2020&amp;dy=2"><span>Wed, 02 Sep 2020 /</span></a></p>

# %%
soup.find('div', id='event-listing').findAll('li')[4].find('h1').find('span').text
# Out:
# 'at Now and Then'

# %%
soup.find('div', id='event-listing').findAll('li')[1]

# %%
soup.find('div', id="event-listing").findAll('li')[1].find(class_='event-item clearfix').find(class_='event-title').find('a').text
# Out:
# "Outdoor Films: Sign o' the Times"

# %%
for x in soup.find('div', id="event-listing").findAll('li'):
    if x.find(class_='eventDate date'):
        print(x.text.replace('/', '').strip())
    if x.find(class_='event-item clearfix') or x.find(class_='event-item clearfix tickets-bkg-logo'):
        print(x.find(class_='event-title').find('a').text)
        print(x.find('h1').find('span').text.replace('at', '').strip())
        print(x.find('p').find('span').text)
# Out:
# Wed, 02 Sep 2020
# Outdoor Films: Sign o' the Times
# Nowadays
# 2
# Sat, 05 Sep 2020
# Cuff Tour: Amine Edge & Dance with Raw Phonics
# Pier 15
# 17
# White Rabbit
# Now and Then
# 7
# Sun, 06 Sep 2020
# Taj Lounge NYC LDW Hip Hop vs. Reggae® Sunday Funday Brunch Party
# Taj Lounge
# 1

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
def scrape_events(events_page_url):
    #Your code here
    resp = requests.get(events_page_url)
    soup = BeautifulSoup(resp.content, 'html.parser')
    
    name_list = []
    date_list = []
    venue_list = []
    attendees_list = []
    
    for x in soup.find('div', id="event-listing").findAll('li'):
        if x.find(class_='eventDate date'):
            date = (x.text.replace('/', '').strip())
        if x.find(class_='event-item clearfix') or x.find(class_='event-item clearfix tickets-bkg-logo'):
            name_list.append(x.find(class_='event-title').find('a').text)
            venue_list.append(x.find('h1').find('span').text.replace('at', '').strip())
            attendees_list.append(x.find('p').find('span').text)
            date_list.append(date)
                
    df = pd.DataFrame({'Event_Name': name_list,
                      'Venue': venue_list,
                      'Event_Date': date_list,
                      'Number_of_Attendees': attendees_list})
    
    #df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
scrape_events('https://www.residentadvisor.net/events/us/newyork')
# Out:
#                                           Event_Name         Venue  \
# 0                   Outdoor Films: Sign o' the Times      Nowadays
# 1     Cuff Tour: Amine Edge & Dance with Raw Phonics       Pier 15
# 2                                       White Rabbit  Now and Then
# 3  Taj Lounge NYC LDW Hip Hop vs. Reggae® Sunday ...    Taj Lounge
#
#          Event_Date Number_of_Attendees
# 0  Wed, 02 Sep 2020                   2
# 1  Sat, 05 Sep 2020                  17
# 2  Sat, 05 Sep 2020                   7
# 3  Sun, 06 Sep 2020                   1

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
'https://www.residentadvisor.net' + soup.find('li', class_='but arrow-right right').find('a')['href']
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2020-09-09'

# %%
url
# Out:
# 'https://www.residentadvisor.net/events/us/newyork'

# %%
def next_page(url):
    #Your code here
    resp = requests.get(url)
    
    back_of_url = soup.find('li', class_='but arrow-right right').find('a')['href']
    next_page_url = 'https://www.residentadvisor.net' + back_of_url
    return next_page_url

# %%
next_page('https://www.residentadvisor.net/events/us/newyork')
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2020-09-09'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here

# %%
#grabs 2 pages

#start with blank dataframe
df1 = pd.DataFrame()

#grab first page
df_first_page = scrape_events('https://www.residentadvisor.net/events/us/newyork')

# %%
df1 = pd.concat([df1, df_first_page])

# %%
df1
# Out:
#                                           Event_Name         Venue  \
# 0                   Outdoor Films: Sign o' the Times      Nowadays
# 1     Cuff Tour: Amine Edge & Dance with Raw Phonics       Pier 15
# 2                                       White Rabbit  Now and Then
# 3  Taj Lounge NYC LDW Hip Hop vs. Reggae® Sunday ...    Taj Lounge
#
#          Event_Date Number_of_Attendees
# 0  Wed, 02 Sep 2020                   2
# 1  Sat, 05 Sep 2020                  17
# 2  Sat, 05 Sep 2020                   7
# 3  Sun, 06 Sep 2020                   1

# %%
#grab url of next page
next_url = next_page('https://www.residentadvisor.net/events/us/newyork')
next_url
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2020-09-09'

# %%
#grab 2nd page
df_second_page = scrape_events(next_url)
df_second_page
# Out:
#                          Event_Name                 Venue        Event_Date  \
# 0                     She Past Away      Le Poisson Rouge  Wed, 09 Sep 2020
# 1  Shake That Midnight Yacht Cruise   Harbor Lights Yacht  Sat, 12 Sep 2020
# 2          Rooftop Yoga Dance Event  Singularity Bushwick  Sun, 13 Sep 2020
# 3          Rooftop Yoga Dance Event  Singularity Bushwick  Mon, 14 Sep 2020
#
#   Number_of_Attendees
# 0                   3
# 1                   2
# 2                   1
# 3                   1

# %%
df2 = pd.concat([df_first_page, df_second_page])
df2
# Out:
#                                           Event_Name                 Venue  \
# 0                   Outdoor Films: Sign o' the Times              Nowadays
# 1     Cuff Tour: Amine Edge & Dance with Raw Phonics               Pier 15
# 2                                       White Rabbit          Now and Then
# 3  Taj Lounge NYC LDW Hip Hop vs. Reggae® Sunday ...            Taj Lounge
# 0                                      She Past Away      Le Poisson Rouge
# 1                   Shake That Midnight Yacht Cruise   Harbor Lights Yacht
# 2                           Rooftop Yoga Dance Event  Singularity Bushwick
# 3                           Rooftop Yoga Dance Event  Singularity Bushwick
#
#          Event_Date Number_of_Attendees
# 0  Wed, 02 Sep 2020                   2
# 1  Sat, 05 Sep 2020                  17
# 2  Sat, 05 Sep 2020                   7
# 3  Sun, 06 Sep 2020                   1
# 0  Wed, 09 Sep 2020                   3
# 1  Sat, 12 Sep 2020                   2
# 2  Sun, 13 Sep 2020                   1
# 3  Mon, 14 Sep 2020                   1

# %%
#start with blank dataframe
df1 = pd.DataFrame()
url = 'https://www.residentadvisor.net/events/us/newyork'

while len(df1) < 1000:
    print(f'Currently have {len(df1)} events scraped')
    
    df_events = scrape_events(url)
    
    df1 = pd.concat([df1, df_events])
    
    try:
        url = next_page(url)
    except:
        break
# Out:
# Currently have 0 events scraped
# Currently have 4 events scraped
# Currently have 8 events scraped
# Currently have 12 events scraped
# Currently have 16 events scraped
# Currently have 20 events scraped
# Currently have 24 events scraped
# Currently have 28 events scraped
# Currently have 32 events scraped
# Currently have 36 events scraped
# Currently have 40 events scraped
# Currently have 44 events scraped
# Currently have 48 events scraped
# Currently have 52 events scraped
# Currently have 56 events scraped
# Currently have 60 events scraped
# Currently have 64 events scraped
# Currently have 68 events scraped
# Currently have 72 events scraped
# Currently have 76 events scraped
# Currently have 80 events scraped
# Currently have 84 events scraped
# Currently have 88 events scraped
# Currently have 92 events scraped
# Currently have 96 events scraped
# Currently have 100 events scraped
# Currently have 104 events scraped
# Currently have 108 events scraped
# Currently have 112 events scraped
# Currently have 116 events scraped
# Currently have 120 events scraped
# Currently have 124 events scraped
# Currently have 128 events scraped
# Currently have 132 events scraped
# Currently have 136 events scraped
# Currently have 140 events scraped
# Currently have 144 events scraped
# Currently have 148 events scraped
# Currently have 152 events scraped
# Currently have 156 events scraped
# Currently have 160 events scraped
# Currently have 164 events scraped
# Currently have 168 events scraped
# Currently have 172 events scraped
# Currently have 176 events scraped
# Currently have 180 events scraped
# Currently have 184 events scraped
# Currently have 188 events scraped
# Currently have 192 events scraped
# Currently have 196 events scraped
# Currently have 200 events scraped
# Currently have 204 events scraped
# Currently have 208 events scraped
# Currently have 212 events scraped
# Currently have 216 events scraped
# Currently have 220 events scraped
# Currently have 224 events scraped
# Currently have 228 events scraped
# Currently have 232 events scraped
# Currently have 236 events scraped
# Currently have 240 events scraped
# Currently have 244 events scraped
# Currently have 248 events scraped
# Currently have 252 events scraped
# Currently have 256 events scraped
# Currently have 260 events scraped
# Currently have 264 events scraped
# Currently have 268 events scraped
# Currently have 272 events scraped
# Currently have 276 events scraped
# Currently have 280 events scraped
# Currently have 284 events scraped
# Currently have 288 events scraped
# Currently have 292 events scraped
# Currently have 296 events scraped
# Currently have 300 events scraped
# Currently have 304 events scraped
# Currently have 308 events scraped
# Currently have 312 events scraped
# Currently have 316 events scraped
# Currently have 320 events scraped
# Currently have 324 events scraped
# Currently have 328 events scraped
# Currently have 332 events scraped
# Currently have 336 events scraped
# Currently have 340 events scraped
# Currently have 344 events scraped
# Currently have 348 events scraped
# Currently have 352 events scraped
# Currently have 356 events scraped
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-110-9c70da1a64c5> in <module>
#       6     print(f'Currently have {len(df1)} events scraped')
#       7
# ----> 8     df_events = scrape_events(url)
#       9
#      10     df1 = pd.concat([df1, df_events])
#
# <ipython-input-82-dd2a81fcf84d> in scrape_events(events_page_url)
#       1 def scrape_events(events_page_url):
#       2     #Your code here
# ----> 3     resp = requests.get(events_page_url)
#       4     soup = BeautifulSoup(resp.content, 'html.parser')
#       5
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\envs\learn-env\lib\http\client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# ~\Anaconda3\envs\learn-env\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\Anaconda3\envs\learn-env\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\Anaconda3\envs\learn-env\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
